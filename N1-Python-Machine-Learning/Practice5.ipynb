# %% [markdown]
# ### 1. 다음 코드와 실행 결과로 나타난 그래프를 보고, 분석한 내용으로 가장 적합한 것은 무엇인가?

# %%
import seaborn as sns
import pandas as pd
import numpy as np

sns.set(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")
sns.boxplot(x="time", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# 1. 봉 차트(candle chart) 그래프이다.
# 2. 점심에 지불하는 금액의 평균이 저녁에 지불하는 금액의 평균보다 크다.
# 3. 저녁에 지불하는 금액의 종류가 점심보다 범위가 다양할 것으로 생각할 수 있다.
# 4. 점심 데이터의 개수가 저녁 데이터의 개수보다 작다.
#
# > 답 : 3
# > boxplot 그래프로 저녁에 지불하는 금액의 평균이 더 크고, 범위가 다양하다. 데이터의 개수는 확인하기 어렵다.

# %% [markdown]
# ### 2. 다음 실행 결과와 같은 그래프를 작성하려고 할 때, 다음 빈칸에 알맞은 코드를 순서대로 나열한 것을 고르시오.
#
# 1. total_bill, tip, smoker
# 2. tip, total_bill, smoker
# 3. tip, smoker, smoker
# 4. total_bill, smoker, tip
#
# > 답 : 2

# %%
tips = sns.load_dataset("tips")
sns.scatterplot(x="tip", y="total_bill", hue="smoker", data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# > 답 : 2

# %% [markdown]
# ### 3. 다음 실행 결과의 데이터를 이용해 분포와 상관관계를 표현하는 그래프를 작성하고자 한다. 이 그래프를 작성하기 위한 적절한 추가 코드는 무엇인가?

# %%
dataset = sns.load_dataset("iris")
dataset.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# 1. sns.jointplot(dataset, hue="species")
# 2. sns.pairplot(dataset, hue="species")
# 3. sns.distplot(dataset, hue="species")
# 4. sns.PairGrid(dataset, hue="species")
#
# > 답 : 2
# > pairplot는 DataSet에 존재하는 Series들 간의 상관관계를 표현함

# %%
# sns.jointplot(dataset, hue="species")
sns.pairplot(dataset, hue="species")
# sns.distplot(dataset, hue="species")
# sns.PairGrid(dataset, hue="species")

# %% [markdown]
# ### 4. 문제 3의 데이터를 이용해 다음과 같은 그래프를 작성하고자 한다. 다음 빈칸에 알맞은 코드를 순서대로 나열한 것을 고르시오.
#
# 1. col, pairplot, "sepal_length", "sepal_width"
# 2. col, scatterplot, "sepal_length", "sepal_width"
# 3. row, scatterplot, "sepal_width", "sepal_length",
# 4. row, pairplot, "sepal_length", "sepal_width"
#
# > 답 : 2

# %%
import seaborn as sns

df = sns.load_dataset('iris')
grid = sns.FacetGrid(data=df, col='species')
grid.map(sns.scatterplot, "sepal_length", "sepal_width")

# %% [markdown]
# ### 5. 맷플롯립(matplotlib)을 사용하여 다음과 같이 여러 개의 그래프를 한 화면에 작성하고자 한다. 다음 빈칸에 알맞은 코드를 순서대로 나열한 것을 고르시오.
#
# 1. 1, 2, 3, 4
# 2. 2, 3, 4, 1
# 3. 3, 4, 1, 2
# 4. 4, 3, 2, 1
#
# > 답 : 3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.subplot(2, 2, 3)
plt.plot([1, 2, 3], 'red')
plt.subplot(2, 2, 4)
plt.plot([1, 2, 3], 'blue')
plt.subplot(2, 2, 1)
plt.plot([1, 2, 3], 'green')
plt.subplot(2, 2, 2)
plt.plot([1, 2, 3], 'black')

plt.show()

# %% [markdown]
# ### 6. 다음 코드를 실행하여 실행 결과의 그래프를 출력하려고 한다. 빈칸에 알맞은 코드를 고르시오.

# %%
sns.set(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")
pivot_df = tips.pivot_table(index="sex", coluxmns="day",
                            values="total_bill", aggfunc="sum")
pivot_df
# Out:
# day       Thur     Fri      Sat      Sun
# sex
# Male    561.44  198.57  1227.35  1269.46
# Female  534.89  127.31   551.05   357.70

# %% [markdown]
# 1. pivot_df.plot.bar(stacked=True, figsize=(10,7))
# 2. pivot_df.plot.bar(figsize=(10,7))
# 3. pivot_df.T.plot.stacked(figsize=(10,7))
# 4. pivot_df.T.plot.bar(stacked=True, figsize=(10,7))
#
# > 답 : 4

# %%
pivot_df.plot.bar(stacked=True, figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
pivot_df.plot.bar(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
pivot_df.T.plot.stacked(figsize=(10,7))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 pivot_df.T.plot.stacked(figsize=(10,7))
#
# AttributeError: 'PlotAccessor' object has no attribute 'stacked'

# %%
pivot_df.T.plot.bar(stacked=True, figsize=(10, 7))

# %% [markdown]
# ### 7. 다음 코드를 실행하여 실행 결과로 나타나는 그래프는 무엇인가?
#
# > 답 : 1

# %%
df = sns.load_dataset('tips')

ax1 = plt.subplot(212)
ax1.margins(0.05)
ax1.scatter(df["total_bill"], df["tip"])

ax2 = plt.subplot(221)
ax2.boxplot(df["total_bill"])

ax3 = plt.subplot(222)
ax3.bar(["Male", "Female"], df.groupby("sex")["total_bill"].mean())

plt.show()

# %% [markdown]
# ### 8. 다음 코드에서 실행 결과와 같은 형태의 그래프를 출력하고자 할 때 빈칸에 들어갈 코드로 적절한 것을 고르시오.
#
# 1. data_example[:idx].sum(axis=0)
# 2. data_example[:idx].sum(axis=1)
# 3. data_example[:idx-1].sum(axis=0)
# 4. data_example.sum(axis=0)
#
# > 답 : 1

# %%
N = 5
ind = np.arange(N)
width = 0.35

data_example = np.random.random_integers(0, 100, size=50).reshape(-1, 5)
print(data_example)
# Out:
# [[57  9 92 47 66]
#  [59 30 54 68 73]
#  [47 50 79 32 73]
#  [24  6 68  3 41]
#  [25 47 70 62 58]
#  [80 67 37 35  6]
#  [34 60 66 41 30]
#  [55 61 89 94 17]
#  [83 96 23 17 28]
#  [65  6 25 41 84]]
# C:\Users\Laeti\AppData\Local\Temp\ipykernel_76516\906622600.py:5: DeprecationWarning: This function is deprecated. Please call randint(0, 100 + 1) instead
#   data_example = np.random.random_integers(0, 100, size=50).reshape(-1, 5)

# %%
for idx in range(len(data_example)):
    plt.bar(
        x=ind, height=data_example[idx],
        width=width, bottom=data_example[:idx].sum(axis=0))

plt.ylabel('Scores')
plt.title('Scores by group')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.show()

# %% [markdown]
# ### 9. 다음 코드를 실행하여 실행 결과로 출력되는 그래프로 올바른 것을 고르시오.
#
# > 답 : 4

# %%
df = sns.load_dataset('iris')
grid = sns.FacetGrid(data=df, col='species')
grid.map(sns.scatterplot, "sepal_length", "sepal_width")

# %% [markdown]
# __10. 시본을 사용하여 다음과 같은 데이터를 바이올린 플롯 형태로 표현하고자 한다. 이때 다음 코드의 매개변수로 적절한 것을 고르시오.__

# %%
sns.set_style("whitegrid")
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 1. x="species", y="sepal_width", data=df
# 2. x="sepal_width", y="species", data=df
# 3. data=df
# 4. "species", "sepal_width"
#
# > 답 : 1

# %%
sns.violinplot(x="species", y="sepal_width", data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>
